# %% [markdown]
# # PA1 Task 4: Open-Set Recognition
#
# This notebook trains Vanilla, GCSC, and PROSER on CIFAR-10, then evaluates open-set recognition on CIFAR-100.

# %%
# 1. Setup repository (Replace with your actual GitHub URL/Token)
REPO_URL = "https://github.com/YOUR_USERNAME/YOUR_REPO_NAME.git"

import os
if not os.path.exists("PA1"):
    # !git clone {REPO_URL} PA1
    
# %cd PA1

# %%
# 2. Install dependencies
# !pip install -q scikit-learn matplotlib pyyaml torchvision Pillow

# %%
# 3. Make Dataset Splits
# !python task4/data/make_splits.py

# %%
# 4. Optional: Run Smoke Test
# !python task4_smoke_test.py

# %%
# 5. Train Models
print("Training Vanilla Baseline...")
# !python task4/train.py --method vanilla

print("Training GCSC...")
# !python task4/train.py --method gcsc

print("Training PROSER...")
# !python task4/train.py --method proser

# %%
# 6. Extract Features & Logits
print("Extracting for Vanilla...")
# !python task4/extract_outputs.py --method vanilla

print("Extracting for GCSC...")
# !python task4/extract_outputs.py --method gcsc

print("Extracting for PROSER...")
# !python task4/extract_outputs.py --method proser

# %%
# 7. Evaluate OSR and Generate Results
# !python task4/evaluate_osr.py
# !python task4/plot_osr.py

# %%
# 8. Zip the results and checkpoints
import shutil
shutil.make_archive("/kaggle/working/task4_results", "zip", "task4/results")
shutil.make_archive("/kaggle/working/task4_checkpoints", "zip", "task4/checkpoints")
print("Zipped results and checkpoints for download!")
